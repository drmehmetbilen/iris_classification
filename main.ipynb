# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/iris.csv")

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             5.0          3.6           1.4          0.2     setosa
# 4             5.4          3.9           1.7          0.4     setosa
# ..            ...          ...           ...          ...        ...
# 142           6.7          3.3           5.7          2.5  virginica
# 143           6.7          3.0           5.2          2.3  virginica
# 144           6.5          3.0           5.2          2.0  virginica
# 145           6.2          3.4           5.4          2.3  virginica
# 146           5.9          3.0           5.1          1.8  virginica
#
# [147 rows x 5 columns]

# %%
def get_distance(sample1, sample2):
    distance_sum = 0
    for i in range(len(sample1)):
        distance_feature = (sample1[i] - sample2[i]) *  (sample1[i] - sample2[i])
        distance_sum+=distance_feature
    
    distance = distance_sum**0.5
    return distance

def sort_array(distance_results):
    for i in range(len(distance_results)):
        for j in range(i+1,len(distance_results)):
            if distance_results[j]["distance_score"]<distance_results[i]["distance_score"]:
                backup  = distance_results[j]
                distance_results[j] = distance_results[i]
                distance_results[i] = backup
    
    return distance_results

# %%
new_sample = [6.3,2.5,5.0,1.9]
k = 3
distance_list = []
for index, row in df.iterrows():
    data_sample = [row["sepal_length"],row["sepal_width"],row["petal_length"],row["petal_width"]]
    d = get_distance(new_sample, data_sample)
    d_result = {
        "index":index,
        "distance_score":d,
        "class":row["species"]
    }
    distance_list.append(d_result)
    sorted_distance_list = sort_array(distance_list)

# %%
sorted_distance_list
# Out:
# [{'index': 121, 'distance_score': 0.24494897427831777, 'class': 'virginica'},
#  {'index': 109, 'distance_score': 0.3741657386773942, 'class': 'virginica'},
#  {'index': 124, 'distance_score': 0.38729833462074154, 'class': 'virginica'},
#  {'index': 71, 'distance_score': 0.41231056256176585, 'class': 'versicolor'},
#  {'index': 82, 'distance_score': 0.47958315233127174, 'class': 'versicolor'},
#  {'index': 131, 'distance_score': 0.5099019513592782, 'class': 'virginica'},
#  {'index': 99, 'distance_score': 0.5477225575051662, 'class': 'virginica'},
#  {'index': 140, 'distance_score': 0.5477225575051662, 'class': 'virginica'},
#  {'index': 125, 'distance_score': 0.5567764362830022, 'class': 'virginica'},
#  {'index': 117, 'distance_score': 0.5830951894845299, 'class': 'virginica'},
#  {'index': 144, 'distance_score': 0.5830951894845302, 'class': 'virginica'},
#  {'index': 111, 'distance_score': 0.6082762530298217, 'class': 'virginica'},
#  {'index': 136, 'distance_score': 0.6244997998398398, 'class': 'virginica'},
#  {'index': 146, 'distance_score': 0.6557438524301997, 'class': 'virginica'},
#  {'index': 76, 'distance_score': 0.670820393249937, 'class': 'versicolor'},
#  {'index': 53, 'distance_score': 0.670820393249937, 'class': 'versicolor'},
#  {'index': 126, 'distance_score': 0.7071067811865474, 'class': 'virginica'},
#  {'index': 67, 'distance_score': 0.7141428428542849, 'class': 'versicolor'},
#  {'index': 101, 'distance_score': 0.7280109889280515, 'class': 'virginica'},
#  {'index': 62, 'distance_score': 0.7348469228349533, 'class': 'versicolor'},
#  {'index': 130, 'distance_score': 0.7416198487095662, 'class': 'virginica'},
#  {'index': 114, 'distance_score': 0.7416198487095663, 'class': 'virginica'},
#  {'index': 108, 'distance_score': 0.7416198487095664, 'class': 'virginica'},
#  {'index': 112, 'distance_score': 0.7745966692414833, 'class': 'virginica'},
#  {'index': 119, 'distance_score': 0.7745966692414834, 'class': 'virginica'},
#  {'index': 143, 'distance_score': 0.7810249675906656, 'class': 'virginica'},
#  {'index': 75, 'distance_score': 0.7937253933193772, 'class': 'versicolor'},
#  {'index': 135, 'distance_score': 0.7937253933193773, 'class': 'virginica'},
#  {'index': 77, 'distance_score': 0.8124038404635958, 'class': 'versicolor'},
#  {'index': 132, 'distance_score': 0.8124038404635958, 'class': 'virginica'},
#  {'index': 69, 'distance_score': 0.8366600265340756, 'class': 'versicolor'},
#  {'index': 90, 'distance_score': 0.8366600265340758, 'class': 'versicolor'},
#  {'index': 72, 'distance_score': 0.8426149773176357, 'class': 'versicolor'},
#  {'index': 113, 'distance_score': 0.8660254037844387, 'class': 'virginica'},
#  {'index': 86, 'distance_score': 0.8717797887081344, 'class': 'versicolor'},
#  {'index': 85, 'distance_score': 0.8774964387392122, 'class': 'versicolor'},
#  {'index': 57, 'distance_score': 0.8774964387392122, 'class': 'versicolor'},
#  {'index': 110, 'distance_score': 0.8888194417315589, 'class': 'virginica'},
#  {'index': 106, 'distance_score': 0.9, 'class': 'virginica'},
#  {'index': 55, 'distance_score': 0.9055385138137413, 'class': 'versicolor'},
#  {'index': 51, 'distance_score': 0.9433981132056607, 'class': 'versicolor'},
#  {'index': 139, 'distance_score': 0.9433981132056607, 'class': 'virginica'},
#  {'index': 50, 'distance_score': 0.9539392014169458, 'class': 'versicolor'},
#  {'index': 137, 'distance_score': 0.9591663046625445, 'class': 'virginica'},
#  {'index': 74, 'distance_score': 0.9746794344808961, 'class': 'versicolor'},
#  {'index': 102, 'distance_score': 1.0099504938362076, 'class': 'virginica'},
#  {'index': 73, 'distance_score': 1.0099504938362078, 'class': 'versicolor'},
#  {'index': 95, 'distance_score': 1.0099504938362078, 'class': 'versicolor'},
#  {'index': 54, 'distance_score': 1.0295630140986998, 'class': 'versicolor'},
#  {'index': 138, 'distance_score': 1.0630145812734648, 'class': 'virginica'},
#  {'index': 64, 'distance_score': 1.0630145812734648, 'class': 'versicolor'},
#  {'index': 145, 'distance_score': 1.0677078252031311, 'class': 'virginica'},
#  {'index': 65, 'distance_score': 1.0723805294763609, 'class': 'versicolor'},
#  {'index': 60, 'distance_score': 1.0999999999999996, 'class': 'versicolor'},
#  {'index': 84, 'distance_score': 1.1135528725660042, 'class': 'versicolor'},
#  {'index': 49, 'distance_score': 1.148912529307606, 'class': 'versicolor'},
#  {'index': 122, 'distance_score': 1.1532562594670797, 'class': 'virginica'},
#  {'index': 134, 'distance_score': 1.1916375287812984, 'class': 'virginica'},
#  {'index': 83, 'distance_score': 1.2124355652982137, 'class': 'versicolor'},
#  {'index': 70, 'distance_score': 1.2206555615733703, 'class': 'versicolor'},
#  {'index': 89, 'distance_score': 1.2247448713915887, 'class': 'versicolor'},
#  {'index': 118, 'distance_score': 1.2247448713915896, 'class': 'virginica'},
#  {'index': 94, 'distance_score': 1.2328828005937948, 'class': 'versicolor'},
#  {'index': 92, 'distance_score': 1.236931687685298, 'class': 'versicolor'},
#  {'index': 97, 'distance_score': 1.2727922061357855, 'class': 'versicolor'},
#  {'index': 142, 'distance_score': 1.2845232578665131, 'class': 'virginica'},
#  {'index': 141, 'distance_score': 1.3076696830622023, 'class': 'virginica'},
#  {'index': 93, 'distance_score': 1.3190905958272916, 'class': 'versicolor'},
#  {'index': 100, 'distance_score': 1.319090595827292, 'class': 'virginica'},
#  {'index': 127, 'distance_score': 1.3379088160259651, 'class': 'virginica'},
#  {'index': 66, 'distance_score': 1.3820274961085255, 'class': 'versicolor'},
#  {'index': 87, 'distance_score': 1.3820274961085255, 'class': 'versicolor'},
#  {'index': 61, 'distance_score': 1.4106735979665883, 'class': 'versicolor'},
#  {'index': 81, 'distance_score': 1.4106735979665885, 'class': 'versicolor'},
#  {'index': 98, 'distance_score': 1.414213562373095, 'class': 'virginica'},
#  {'index': 88, 'distance_score': 1.414213562373095, 'class': 'versicolor'},
#  {'index': 52, 'distance_score': 1.42828568570857, 'class': 'versicolor'},
#  {'index': 104, 'distance_score': 1.4999999999999993, 'class': 'virginica'},
#  {'index': 123, 'distance_score': 1.5198684153570665, 'class': 'virginica'},
#  {'index': 68, 'distance_score': 1.5297058540778354, 'class': 'versicolor'},
#  {'index': 128, 'distance_score': 1.584297951775486, 'class': 'virginica'},
#  {'index': 58, 'distance_score': 1.6462077633154326, 'class': 'versicolor'},
#  {'index': 79, 'distance_score': 1.6522711641858305, 'class': 'versicolor'},
#  {'index': 105, 'distance_score': 1.6911534525287761, 'class': 'virginica'},
#  {'index': 63, 'distance_score': 1.7233687939614086, 'class': 'versicolor'},
#  {'index': 80, 'distance_score': 1.7748239349298844, 'class': 'versicolor'},
#  {'index': 78, 'distance_score': 1.8520259177452134, 'class': 'versicolor'},
#  {'index': 133, 'distance_score': 1.8920887928424501, 'class': 'virginica'},
#  {'index': 107, 'distance_score': 1.8947295321496418, 'class': 'virginica'},
#  {'index': 103, 'distance_score': 2.1307275752662513, 'class': 'virginica'},
#  {'index': 120, 'distance_score': 2.224859546128699, 'class': 'virginica'},
#  {'index': 59, 'distance_score': 2.2360679774997894, 'class': 'versicolor'},
#  {'index': 91, 'distance_score': 2.3302360395462087, 'class': 'versicolor'},
#  {'index': 56, 'distance_score': 2.3811761799581315, 'class': 'versicolor'},
#  {'index': 116, 'distance_score': 2.395829710142188, 'class': 'virginica'},
#  {'index': 96, 'distance_score': 2.4657656011875906, 'class': 'versicolor'},
#  {'index': 129, 'distance_score': 2.4939927826679855, 'class': 'virginica'},
#  {'index': 115, 'distance_score': 2.5748786379167465, 'class': 'virginica'},
#  {'index': 22, 'distance_score': 3.8639358172723313, 'class': 'setosa'},
#  {'index': 43, 'distance_score': 3.871692136521188, 'class': 'setosa'},
#  {'index': 19, 'distance_score': 3.9242833740697165, 'class': 'setosa'},
#  {'index': 17, 'distance_score': 3.937003937005905, 'class': 'setosa'},
#  {'index': 23, 'distance_score': 3.9446165846632044, 'class': 'setosa'},
#  {'index': 4, 'distance_score': 3.9887341350358256, 'class': 'setosa'},
#  {'index': 42, 'distance_score': 3.9924929555354254, 'class': 'setosa'},
#  {'index': 30, 'distance_score': 4.014971979976946, 'class': 'setosa'},
#  {'index': 25, 'distance_score': 4.038564101261734, 'class': 'setosa'},
#  {'index': 24, 'distance_score': 4.048456495999432, 'class': 'setosa'},
#  {'index': 29, 'distance_score': 4.1303752856126765, 'class': 'setosa'},
#  {'index': 26, 'distance_score': 4.165333119931706, 'class': 'setosa'},
#  {'index': 20, 'distance_score': 4.168932717135166, 'class': 'setosa'},
#  {'index': 9, 'distance_score': 4.170131892398609, 'class': 'setosa'},
#  {'index': 38, 'distance_score': 4.170131892398609, 'class': 'setosa'},
#  {'index': 28, 'distance_score': 4.183300132670377, 'class': 'setosa'},
#  {'index': 10, 'distance_score': 4.1844951905815355, 'class': 'setosa'},
#  {'index': 45, 'distance_score': 4.192851058647325, 'class': 'setosa'},
#  {'index': 47, 'distance_score': 4.192851058647326, 'class': 'setosa'},
#  {'index': 6, 'distance_score': 4.2, 'class': 'setosa'},
#  {'index': 33, 'distance_score': 4.220189569201838, 'class': 'setosa'},
#  {'index': 36, 'distance_score': 4.220189569201838, 'class': 'setosa'},
#  {'index': 8, 'distance_score': 4.220189569201838, 'class': 'setosa'},
#  {'index': 27, 'distance_score': 4.22729227756965, 'class': 'setosa'},
#  {'index': 18, 'distance_score': 4.235563716909474, 'class': 'setosa'},
#  {'index': 16, 'distance_score': 4.237924020083418, 'class': 'setosa'},
#  {'index': 44, 'distance_score': 4.244997055358225, 'class': 'setosa'},
#  {'index': 1, 'distance_score': 4.249705872175156, 'class': 'setosa'},
#  {'index': 48, 'distance_score': 4.263801121065568, 'class': 'setosa'},
#  {'index': 35, 'distance_score': 4.268489194082609, 'class': 'setosa'},
#  {'index': 0, 'distance_score': 4.27668095606862, 'class': 'setosa'},
#  {'index': 14, 'distance_score': 4.29767378938886, 'class': 'setosa'},
#  {'index': 11, 'distance_score': 4.324349662087931, 'class': 'setosa'},
#  {'index': 15, 'distance_score': 4.325505750776434, 'class': 'setosa'},
#  {'index': 3, 'distance_score': 4.330127018922194, 'class': 'setosa'},
#  {'index': 39, 'distance_score': 4.352011029397789, 'class': 'setosa'},
#  {'index': 5, 'distance_score': 4.384062043356595, 'class': 'setosa'},
#  {'index': 46, 'distance_score': 4.38520238985614, 'class': 'setosa'},
#  {'index': 31, 'distance_score': 4.388621651498338, 'class': 'setosa'},
#  {'index': 32, 'distance_score': 4.402272140611028, 'class': 'setosa'},
#  {'index': 34, 'distance_score': 4.417012565071555, 'class': 'setosa'},
#  {'index': 40, 'distance_score': 4.41927595879687, 'class': 'setosa'},
#  {'index': 7, 'distance_score': 4.42944691807002, 'class': 'setosa'},
#  {'index': 2, 'distance_score': 4.430575583375145, 'class': 'setosa'},
#  {'index': 13, 'distance_score': 4.453088815642463, 'class': 'setosa'},
#  {'index': 37, 'distance_score': 4.521061822182927, 'class': 'setosa'},
#  {'index': 41, 'distance_score': 4.547526800360829, 'class': 'setosa'},
#  {'index': 12, 'distance_score': 4.764451699828638, 'class': 'setosa'},
#  {'index': 21, 'distance_score': 4.794788837894741, 'class': 'setosa'}]
